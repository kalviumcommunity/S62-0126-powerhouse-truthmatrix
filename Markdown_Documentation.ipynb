# %%
# Markdown Documentation in Jupyter

This notebook demonstrates how to use Markdown for clear documentation.

## Steps Covered
- Headings
- Lists
- Inline code
- Code blocks

### Example of Inline Code
We use `print()` to display output.

### Example Code Block
```python
for i in range(5):
    print(i)

**Code Cell**
```python
print("Markdown Milestone Completed")

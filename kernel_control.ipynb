# %%
x = 10
x
# Out:
# 10

# %%
y = x + 5
y
# Out:
# 15

# %%
while True:
    pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 while True:
# ----> 2     pass
#
# KeyboardInterrupt:

# %% [markdown]
# ## Kernel Control Demonstration
#
# This notebook demonstrates:
# - Controlled cell execution
# - Kernel state retention
# - Interrupting a running cell
# - Restarting the kernel safely
